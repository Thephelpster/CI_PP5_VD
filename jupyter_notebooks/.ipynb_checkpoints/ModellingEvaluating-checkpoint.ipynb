# %% [markdown]
# # **Modelling and Evaluation**

# %% [markdown]
# ## Objectives
#
# * Answer business requirement 2:
#     * The client is interested in being able to tell if a given image is a vehicle or not.
#
# ## Inputs
#
# * The image shape embeddings from the pickle file.
# * The images are taken from the subfolders of test, train and validation folders.
#
# * ── inputs
# * 		└──vehicle_dataset
# * 		      └──vehicle
# * 					├── test
# * 					│	├── non-vehicles
# * 					│	└── vehicles
# * 					├── train
# * 					│	├── non-vehicles
# * 					│	└── vehicles
# * 					└── validation
# * 							├── non-vehicles
# * 							└── vehicles
#
# ## Outputs
#
#
# ## Additional Comments

# %% [markdown]
# ---

# %% [markdown]
# # Import Packages

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import plotly.express as px
sns.set_style("white")
from matplotlib.image import imread

# %% [markdown]
# ---

# %% [markdown]
# # Change Working Directory

# %% [markdown]
# Change the working directory from its current folder to its parent folder
#
# * We access the current directory with os.getcwd()

# %%
current_dir = os.getcwd()
current_dir
# Out:
# '/workspaces/CI_PP5_VD/jupyter_notebooks'

# %% [markdown]
# We want to make the parent of the current directory the new current directory
#
# * os.path.dirname() gets the parent directory
# * os.chdir() defines the new current directory

# %%
os.chdir(os.path.dirname(current_dir))
print("You set a new current directory")
# Out:
# You set a new current directory

# %% [markdown]
# Confirm the new current directory

# %%
current_dir = os.getcwd()
current_dir
# Out:
# '/workspaces/CI_PP5_VD'

# %% [markdown]
# ## Set Input Directories

# %% [markdown]
# Set train, validation and test paths.

# %%
my_data_dir = 'inputs/vehicle-detection-image-set/data'
train_path = my_data_dir + '/train' 
val_path = my_data_dir + '/validation'
test_path = my_data_dir + '/test'

# %% [markdown]
# ## Set Output Directory

# %%
version = 'v1'
file_path = f'outputs/{version}'

if 'outputs' in os.listdir(current_dir) and version in os.listdir(current_dir + '/outputs'):
    print('Old version is already available create a new version.')
    pass
else:
    os.makedirs(name=file_path)
# Out:
# Old version is already available create a new version.

# %% [markdown]
# ## Set Labels

# %%
labels = os.listdir(train_path)
print('Label for the images are', labels)
# Out:
# Label for the images are ['vehicles', 'non-vehicles']

# %% [markdown]
# ## Set Image Shape

# %%
import joblib
version = 'v1'
image_shape = joblib.load(filename=f"outputs/{version}/image_shape.pkl")
image_shape
# Out:
# (64, 64, 3)

# %% [markdown]
# ---

# %% [markdown]
# # Image Distribution

# %% [markdown]
# ## Count Number of Images per Label and Set

# %%
df_freq = pd.DataFrame([])
for folder in ['train', 'validation', 'test']:
    for label in labels:
        df_freq = df_freq.append(
            pd.Series(data={'Set': folder,
                            'Label': label,
                            'Count': int(len(os.listdir(my_data_dir + '/' + folder + '/' + label)))}
                      ),
            ignore_index=True
        )

        print(
            f"* {folder} - {label}: {len(os.listdir(my_data_dir+'/'+ folder + '/' + label))} images")

print("\n")
# Out:
# * train - vehicles: 6154 images
# * train - non-vehicles: 6277 images
# * validation - vehicles: 879 images
# * validation - non-vehicles: 896 images
# * test - vehicles: 1759 images
# * test - non-vehicles: 1795 images

# %% [markdown]
# ## Pie Chart of Set Distribution

# %%
folders = os.listdir(my_data_dir)
data=[]
for folder in folders:
    for label in labels:
        n=int(len(os.listdir(my_data_dir + '/' + folder + '/' + label)))
        n+=n
    data.append(n)

px = 1/plt.rcParams['figure.dpi'] 
plt.subplots(figsize=(800*px, 250*px))
colors = sns.color_palette('pastel')[0:5]
plt.pie(data, labels = folders, colors = colors, autopct='%.0f%%')
plt.title('Vehicle Data Set Distribution')
plt.savefig(f'{file_path}/sets_distribution_pie.png',
            bbox_inches='tight', dpi=150)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # Image Data Augmentation

# %% [markdown]
# ## Import ImageDataGenerator

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# ## Initialize ImageDataGenerator

# %%
augmented_image_data = ImageDataGenerator(rotation_range=15,
                                          width_shift_range=0.1,
                                          height_shift_range=0.1,
                                          shear_range=15,
                                          zoom_range=0.2,
                                          horizontal_flip=True,
                                          vertical_flip=True,
                                          fill_mode='nearest',
                                          rescale=1./255,
                                          brightness_range=[0.5, 1.5],
                                          )

# %% [markdown]
# ## Set Batch Size

# %%
batch_size = 40

# %% [markdown]
# ## Augmentation of the Training Image Dataset

# %%
train_set = augmented_image_data.flow_from_directory(train_path,
                                                     target_size=image_shape[:2],
                                                     color_mode='rgb',
                                                     batch_size=batch_size,
                                                     class_mode='categorical',
                                                     shuffle=True
                                                     )

train_set.class_indices
# Out:
# Found 12431 images belonging to 2 classes.
# {'non-vehicles': 0, 'vehicles': 1}

# %% [markdown]
# ## Augmentation of the Validation Image Dataset

# %%
validation_set = ImageDataGenerator(rescale=1./255).flow_from_directory(val_path,
                                                                        target_size=image_shape[:2],
                                                                        color_mode='rgb',
                                                                        batch_size=batch_size,
                                                                        class_mode='categorical',
                                                                        shuffle=False
                                                                        )

validation_set.class_indices
# Out:
# Found 1775 images belonging to 2 classes.
# {'non-vehicles': 0, 'vehicles': 1}

# %% [markdown]
# ## Augmentation of the Test Image Dataset

# %%
test_set = ImageDataGenerator(rescale=1./255).flow_from_directory(test_path,
                                                                  target_size=image_shape[:2],
                                                                  color_mode='rgb',
                                                                  batch_size=batch_size,
                                                                  class_mode='categorical',
                                                                  shuffle=False
                                                                  )

test_set.class_indices
# Out:
# Found 3554 images belonging to 2 classes.
# {'non-vehicles': 0, 'vehicles': 1}

# %% [markdown]
# ## Plot Augmented Training Image Set

# %%
for i in range(3):
    img, label = train_set.next()
    print(img.shape)
    plt.imshow(img[0])
    plt.show()
# Out:
# (40, 64, 64, 3)
# (40, 64, 64, 3)
# (40, 64, 64, 3)

# %% [markdown]
# ## Plot Augmented Validation Image Set

# %%
for i in range(3):
    img, label = validation_set.next()
    print(img.shape)
    plt.imshow(img[0])
    plt.show()
# Out:
# (40, 64, 64, 3)
# (40, 64, 64, 3)
# (40, 64, 64, 3)

# %% [markdown]
# ## Plot Augmented Test Image Set

# %%
for i in range(3):
    img, label = test_set.next()
    print(img.shape)
    plt.imshow(img[0])
    plt.show()
# Out:
# (40, 64, 64, 3)
# (40, 64, 64, 3)
# (40, 64, 64, 3)

# %% [markdown]
# ## Save class_indices

# %%
joblib.dump(value=train_set.class_indices,
            filename=f"{file_path}/class_indices.pkl")
# Out:
# ['outputs/v1/class_indices.pkl']

# %% [markdown]
# ---

# %% [markdown]
# # Model Creation

# %% [markdown]
# ## Import Model Packages

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras import models, layers, regularizers
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Conv2D, MaxPooling2D, BatchNormalization, LeakyReLU
from tensorflow.keras.optimizers import RMSprop, Adam, Adagrad

# %% [markdown]
# ## Model

# %% [markdown]
# ## Hypertuning the Model

# %%
def create_model():
    model = Sequential()

    model.add(Conv2D(32, (3, 3), input_shape=image_shape, activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(32, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))      
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Flatten())
    
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(.2))

    model.add(Dense(2, activation='softmax')) 

    model.compile(loss='categorical_crossentropy', 
                  optimizer='adagrad',
                  metrics=['accuracy'])

    return model

# %% [markdown]
# ## Model Summary

# %%
create_model().summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 62, 62, 32)        896
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 31, 31, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 29, 29, 32)        9248
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 12, 12, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                147520
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 176,290
# Trainable params: 176,290
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Call Backs

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

early_stop = EarlyStopping(monitor='val_accuracy',mode='max',verbose=1, patience=2)
m_checkpoint = ModelCheckpoint(filepath='outputs/v1/vehicle_detection_model.h5', monitor='val_accuracy', mode='max', save_best_only=True)

# %% [markdown]
# ## Fit Model for Training

# %%
model = create_model()
model.fit(train_set,
          batch_size=batch_size,
          epochs=32,
          steps_per_epoch=len(train_set.classes) // batch_size,
          validation_data=validation_set,
          callbacks=[early_stop, m_checkpoint],
          verbose=1
          )
# Out:
# 2024-01-05 17:50:40.951280: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/32
# 310/310 [==============================] - 249s 792ms/step - loss: 0.6642 - accuracy: 0.6527 - val_loss: 0.6388 - val_accuracy: 0.7296
# Epoch 2/32
# 310/310 [==============================] - 236s 760ms/step - loss: 0.5938 - accuracy: 0.7309 - val_loss: 0.5499 - val_accuracy: 0.7656
# Epoch 3/32
# 310/310 [==============================] - 232s 746ms/step - loss: 0.5187 - accuracy: 0.7668 - val_loss: 0.4580 - val_accuracy: 0.8146
# Epoch 4/32
# 310/310 [==============================] - 237s 763ms/step - loss: 0.4664 - accuracy: 0.7949 - val_loss: 0.4001 - val_accuracy: 0.8372
# Epoch 5/32
# 310/310 [==============================] - 212s 682ms/step - loss: 0.4349 - accuracy: 0.8115 - val_loss: 0.3674 - val_accuracy: 0.8485
# Epoch 6/32
# 310/310 [==============================] - 200s 644ms/step - loss: 0.4139 - accuracy: 0.8207 - val_loss: 0.3452 - val_accuracy: 0.8530
# Epoch 7/32
# 310/310 [==============================] - 209s 671ms/step - loss: 0.3999 - accuracy: 0.8273 - val_loss: 0.3349 - val_accuracy: 0.8546
# Epoch 8/32
# 310/310 [==============================] - 225s 724ms/step - loss: 0.3914 - accuracy: 0.8328 - val_loss: 0.3390 - val_accuracy: 0.8541
# Epoch 9/32
# 310/310 [==============================] - 172s 554ms/step - loss: 0.3803 - accuracy: 0.8384 - val_loss: 0.3444 - val_accuracy: 0.8462
# Epoch 00009: early stopping

# %% [markdown]
# ## Load Best Saved Model

# %%
from keras.models import load_model

load_model('outputs/v1/vehicle_detection_model.h5')
