# %% [markdown]
# # **Modelling and Evaluation**

# %% [markdown]
# ## Objectives
#
# * Answer business requirement 2:
#     * The client is interested in being able to tell if a given image is a vehicle or not.
#
# ## Inputs
#
# * The image shape embeddings from the pickle file.
# * The images are taken from the subfolders of test, train and validation folders.
#
# * ── inputs
# * 		└──vehicle_dataset
# * 		      └──vehicle
# * 					├── test
# * 					│	├── non-vehicles
# * 					│	└── vehicles
# * 					├── train
# * 					│	├── non-vehicles
# * 					│	└── vehicles
# * 					└── validation
# * 							├── non-vehicles
# * 							└── vehicles
#
# ## Outputs
#
#
# ## Additional Comments

# %% [markdown]
# ---

# %% [markdown]
# # Import Packages

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import plotly.express as px
sns.set_style("white")
from matplotlib.image import imread

# %% [markdown]
# ---

# %% [markdown]
# # Change Working Directory

# %% [markdown]
# Change the working directory from its current folder to its parent folder
#
# * We access the current directory with os.getcwd()

# %%
current_dir = os.getcwd()
current_dir
# Out:
# '/workspaces/CI_PP5_VD/jupyter_notebooks'

# %% [markdown]
# We want to make the parent of the current directory the new current directory
#
# * os.path.dirname() gets the parent directory
# * os.chdir() defines the new current directory

# %%
os.chdir(os.path.dirname(current_dir))
print("You set a new current directory")
# Out:
# You set a new current directory

# %% [markdown]
# Confirm the new current directory

# %%
current_dir = os.getcwd()
current_dir
# Out:
# '/workspaces/CI_PP5_VD'

# %% [markdown]
# ## Set Input Directories

# %% [markdown]
# Set train, validation and test paths.

# %%
my_data_dir = 'inputs/vehicle-detection-image-set/data'
train_path = my_data_dir + '/train' 
val_path = my_data_dir + '/validation'
test_path = my_data_dir + '/test'

# %% [markdown]
# ## Set Output Directory

# %%
version = 'v1'
file_path = f'outputs/{version}'

if 'outputs' in os.listdir(current_dir) and version in os.listdir(current_dir + '/outputs'):
    print('Old version is already available create a new version.')
    pass
else:
    os.makedirs(name=file_path)
# Out:
# Old version is already available create a new version.

# %% [markdown]
# ## Set Labels

# %%
labels = os.listdir(train_path)
print('Label for the images are', labels)
# Out:
# Label for the images are ['vehicles', 'non-vehicles']

# %% [markdown]
# ## Set Image Shape

# %%
import joblib
version = 'v1'
image_shape = joblib.load(filename=f"outputs/{version}/image_shape.pkl")
image_shape
# Out:
# (64, 64, 3)

# %% [markdown]
# ---

# %% [markdown]
# # Image Distribution

# %% [markdown]
# ## Count Number of Images per Label and Set

# %%
df_freq = pd.DataFrame([])
for folder in ['train', 'validation', 'test']:
    for label in labels:
        df_freq = df_freq.append(
            pd.Series(data={'Set': folder,
                            'Label': label,
                            'Count': int(len(os.listdir(my_data_dir + '/' + folder + '/' + label)))}
                      ),
            ignore_index=True
        )

        print(
            f"* {folder} - {label}: {len(os.listdir(my_data_dir+'/'+ folder + '/' + label))} images")

print("\n")

total_label_distribution = df_freq.groupby('Label')['Count'].sum()

report = "Total dataset balance report:\n"
for label, count in total_label_distribution.items():
    report += f"Label - {label}: {int(count)} images\n"

print(report)
# Out:
# * train - vehicles: 6154 images
# * train - non-vehicles: 6277 images
# * validation - vehicles: 879 images
# * validation - non-vehicles: 896 images
# * test - vehicles: 1759 images
# * test - non-vehicles: 1795 images
#
#
# Total dataset balance report:
# Label - non-vehicles: 8968 images
# Label - vehicles: 8792 images

# %% [markdown]
# ## Pie Chart of Set Distribution

# %%
folders = os.listdir(my_data_dir)
data=[]
for folder in folders:
    for label in labels:
        n=int(len(os.listdir(my_data_dir + '/' + folder + '/' + label)))
        n+=n
    data.append(n)

px = 1/plt.rcParams['figure.dpi'] 
plt.subplots(figsize=(800*px, 250*px))
colors = sns.color_palette('pastel')[0:5]
plt.pie(data, labels = folders, colors = colors, autopct='%.0f%%')
plt.title('Vehicle Data Set Distribution')
plt.savefig(f'{file_path}/sets_distribution_pie.png',
            bbox_inches='tight', dpi=150)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # Image Data Augmentation

# %% [markdown]
# ## Import ImageDataGenerator

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# ## Initialize ImageDataGenerator

# %%
augmented_image_data = ImageDataGenerator(rotation_range=15,
                                          width_shift_range=0.1,
                                          height_shift_range=0.1,
                                          shear_range=0.5,
                                          vertical_flip=True,
                                          fill_mode='nearest',
                                          rescale=1.0/255.0,
                                          brightness_range=[0.5, 1.5],
                                          )

# %% [markdown]
# ## Set Batch Size

# %%
batch_size = 25

# %% [markdown]
# ## Augmentation of the Training Image Dataset

# %%
train_set = augmented_image_data.flow_from_directory(train_path,
                                                     target_size=image_shape[:2],
                                                     color_mode='rgb',
                                                     batch_size=batch_size,
                                                     class_mode='categorical',
                                                     shuffle=True
                                                     )

train_set.class_indices
# Out:
# Found 12431 images belonging to 2 classes.
# {'non-vehicles': 0, 'vehicles': 1}

# %% [markdown]
# ## Augmentation of the Validation Image Dataset

# %%
validation_set = ImageDataGenerator(rescale=1./255).flow_from_directory(val_path,
                                                                        target_size=image_shape[:2],
                                                                        color_mode='rgb',
                                                                        batch_size=batch_size,
                                                                        class_mode='categorical',
                                                                        shuffle=True
                                                                        )

validation_set.class_indices
# Out:
# Found 1775 images belonging to 2 classes.
# {'non-vehicles': 0, 'vehicles': 1}

# %% [markdown]
# ## Augmentation of the Test Image Dataset

# %%
test_set = ImageDataGenerator(rescale=1./255).flow_from_directory(test_path,
                                                                  target_size=image_shape[:2],
                                                                  color_mode='rgb',
                                                                  batch_size=batch_size,
                                                                  class_mode='categorical',
                                                                  shuffle=True
                                                                  )

test_set.class_indices
# Out:
# Found 3554 images belonging to 2 classes.
# {'non-vehicles': 0, 'vehicles': 1}

# %% [markdown]
# ## Plot Augmented Training Image Set

# %%
for i in range(3):
    img, label = train_set.next()
    print(img.shape)
    plt.imshow(img[0])
    plt.show()
# Out:
# (25, 64, 64, 3)
# (25, 64, 64, 3)
# (25, 64, 64, 3)

# %% [markdown]
# ## Plot Augmented Validation Image Set

# %%
for i in range(3):
    img, label = validation_set.next()
    print(img.shape)
    plt.imshow(img[0])
    plt.show()
# Out:
# (25, 64, 64, 3)
# (25, 64, 64, 3)
# (25, 64, 64, 3)

# %% [markdown]
# ## Plot Augmented Test Image Set

# %%
for i in range(3):
    img, label = test_set.next()
    print(img.shape)
    plt.imshow(img[0])
    plt.show()
# Out:
# (25, 64, 64, 3)
# (25, 64, 64, 3)
# (25, 64, 64, 3)

# %% [markdown]
# ## Save class_indices

# %%
joblib.dump(value=train_set.class_indices,
            filename=f"{file_path}/class_indices.pkl")
# Out:
# ['outputs/v1/class_indices.pkl']

# %% [markdown]
# ---

# %% [markdown]
# # Model Creation

# %% [markdown]
# ## Import Model Packages

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras import models, layers, regularizers
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Conv2D, MaxPooling2D, BatchNormalization, LeakyReLU
from tensorflow.keras.optimizers import RMSprop, Adam, Adagrad

# %% [markdown]
# ## Model

# %% [markdown]
# ## Hypertuning the Model

# %%
def create_model():
    model = Sequential()

    model.add(Conv2D(32, (3, 3), input_shape=image_shape, activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))      
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Flatten())
    
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(.2))

    model.add(Dense(2, activation='softmax')) 

    model.compile(loss='binary_crossentropy', 
                  optimizer='adagrad',
                  metrics=['accuracy'])

    return model

# %% [markdown]
# ## Model Summary

# %%
create_model().summary()
# Out:
# 2024-01-10 15:16:08.266440: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 62, 62, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 31, 31, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 29, 29, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 12, 12, 64)        36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 2304)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               295040
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 351,618
# Trainable params: 351,618
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Call Backs

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='val_loss', patience=3)

# %% [markdown]
# ## Fit Model for Training

# %%
model = create_model()
model.fit(train_set,
          batch_size=batch_size,
          epochs=25,
          steps_per_epoch=len(train_set.classes) // batch_size,
          validation_data=validation_set,
          callbacks=[early_stop],
          verbose=1
          )
# Out:
# 2024-01-10 15:16:17.450833: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/25
# 497/497 [==============================] - 203s 386ms/step - loss: 0.6850 - accuracy: 0.6199 - val_loss: 0.6755 - val_accuracy: 0.7127
# Epoch 2/25
# 497/497 [==============================] - 149s 300ms/step - loss: 0.6606 - accuracy: 0.7026 - val_loss: 0.6377 - val_accuracy: 0.7465
# Epoch 3/25
# 497/497 [==============================] - 137s 275ms/step - loss: 0.6043 - accuracy: 0.7338 - val_loss: 0.5544 - val_accuracy: 0.7831
# Epoch 4/25
# 497/497 [==============================] - 143s 287ms/step - loss: 0.5267 - accuracy: 0.7666 - val_loss: 0.4518 - val_accuracy: 0.8310
# Epoch 5/25
# 497/497 [==============================] - 147s 296ms/step - loss: 0.4659 - accuracy: 0.7969 - val_loss: 0.4119 - val_accuracy: 0.8310
# Epoch 6/25
# 497/497 [==============================] - 164s 330ms/step - loss: 0.4292 - accuracy: 0.8163 - val_loss: 0.3741 - val_accuracy: 0.8411
# Epoch 7/25
# 497/497 [==============================] - 160s 322ms/step - loss: 0.4072 - accuracy: 0.8268 - val_loss: 0.3425 - val_accuracy: 0.8546
# Epoch 8/25
# 497/497 [==============================] - 152s 306ms/step - loss: 0.3928 - accuracy: 0.8335 - val_loss: 0.3213 - val_accuracy: 0.8699
# Epoch 9/25
# 497/497 [==============================] - 147s 295ms/step - loss: 0.3806 - accuracy: 0.8378 - val_loss: 0.3283 - val_accuracy: 0.8546
# Epoch 10/25
# 497/497 [==============================] - 141s 284ms/step - loss: 0.3675 - accuracy: 0.8489 - val_loss: 0.3112 - val_accuracy: 0.8637
# Epoch 11/25
# 497/497 [==============================] - 152s 305ms/step - loss: 0.3641 - accuracy: 0.8436 - val_loss: 0.3074 - val_accuracy: 0.8631
# Epoch 12/25
# 497/497 [==============================] - 161s 323ms/step - loss: 0.3519 - accuracy: 0.8514 - val_loss: 0.2896 - val_accuracy: 0.8727
# Epoch 13/25
# 497/497 [==============================] - 170s 342ms/step - loss: 0.3470 - accuracy: 0.8547 - val_loss: 0.3097 - val_accuracy: 0.8642
# Epoch 14/25
# 497/497 [==============================] - 163s 327ms/step - loss: 0.3408 - accuracy: 0.8573 - val_loss: 0.2879 - val_accuracy: 0.8721
# Epoch 15/25
# 497/497 [==============================] - 153s 307ms/step - loss: 0.3315 - accuracy: 0.8618 - val_loss: 0.3035 - val_accuracy: 0.8670
# Epoch 16/25
# 497/497 [==============================] - 182s 365ms/step - loss: 0.3281 - accuracy: 0.8641 - val_loss: 0.2778 - val_accuracy: 0.8766
# Epoch 17/25
# 497/497 [==============================] - 170s 341ms/step - loss: 0.3262 - accuracy: 0.8625 - val_loss: 0.2972 - val_accuracy: 0.8715
# Epoch 18/25
# 497/497 [==============================] - 163s 328ms/step - loss: 0.3181 - accuracy: 0.8692 - val_loss: 0.3013 - val_accuracy: 0.8682
# Epoch 19/25
# 497/497 [==============================] - 159s 319ms/step - loss: 0.3159 - accuracy: 0.8668 - val_loss: 0.2863 - val_accuracy: 0.8744

# %% [markdown]
# ## Load Best Saved Model

# %%
model.save('outputs/v1/vehicle_detection_model.h5')

# %% [markdown]
# ---

# %% [markdown]
# # Model Performance

# %% [markdown]
# ## Model Learning Curve

# %%
losses = pd.DataFrame(model.history.history)

losses[['loss', 'val_loss']].plot(style='.-')
plt.title("Loss")
plt.savefig(f'{file_path}/model_training_losses.png', bbox_inches='tight',
            dpi=150)
plt.show()

print("\n")
losses[['accuracy', 'val_accuracy']].plot(style='.-')
plt.title("Accuracy")
plt.savefig(f'{file_path}/model_training_acc.png', bbox_inches='tight',
            dpi=150)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# ## Import Packages

# %%
labels
# Out:
# ['vehicles', 'non-vehicles']

# %%
import sklearn
import sklearn.metrics as metrics
from sklearn.metrics import classification_report, confusion_matrix, f1_score, accuracy_score

# %%
validation_set.reset()

x_true, y_true = next(test_set)
preds = np.argmax(model.predict(test_set), axis=1)
y_pred = np.rint(preds)
y_true = test_set.labels

# %%
cm = confusion_matrix(y_true,y_pred)

classes=list(test_set.class_indices.keys()) 
length=len(classes)
plt.figure(figsize=(8, 5))
sns.heatmap(cm, annot=True, vmin=0, fmt='g', cmap='BuPu', cbar=False)       
plt.xticks(np.arange(length)+.5, classes, rotation= 0, fontsize=8)
plt.yticks(np.arange(length)+.3, classes, rotation=90, fontsize=8)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.savefig(f'{file_path}/confusion_matrix.png',
            bbox_inches='tight', dpi=150)
plt.show()

# %% [markdown]
# ## Load Best Saved Model

# %%
from keras.models import load_model

load_model('outputs/v1/vehicle_detection_model.h5')

# %% [markdown]
# ## Evaluate Model Using Test Set

# %%
evaluation = model.evaluate(test_set)
# Out:
# 143/143 [==============================] - 11s 76ms/step - loss: 0.2794 - accuracy: 0.8666

# %% [markdown]
# ## Save Evaluation Pickle

# %%
joblib.dump(value=evaluation,
            filename=f"outputs/{version}/evaluation.pkl")
# Out:
# ['outputs/v1/evaluation.pkl']

# %% [markdown]
# ---

# %% [markdown]
# # Predict on New Data

# %%
from tensorflow.keras.preprocessing import image

pointer = 44

label = labels[0]

pil_image = image.load_img(test_path + '/' + label + '/' + os.listdir(test_path+'/' + label)[pointer],
                           target_size=image_shape, color_mode='rgb')
print(f'Image shape: {pil_image.size}, Image mode: {pil_image.mode}')
pil_image
# Out:
# Image shape: (64, 64), Image mode: RGB
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=64x64>

# %%
my_image = image.img_to_array(pil_image)
my_image = np.expand_dims(my_image, axis=0)/255
print(my_image.shape)
# Out:
# (1, 64, 64, 3)

# %%
pred_proba = model.predict(my_image)[0, 0]

target_map = {v: k for k, v in train_set.class_indices.items()}
pred_class = target_map[pred_proba > 0.5]

if pred_class == target_map[0]:
    pred_proba = 1 - pred_proba

print(pred_proba)
print(f"{pred_class} {round(pred_proba*100, 2)}%")
# Out:
# 0.963161289691925
# non-vehicles 96.32%
